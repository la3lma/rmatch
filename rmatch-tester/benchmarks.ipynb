# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('logs/logfile-2023-05-08-20:37:45.csv')
# Out:
#      NoOfRegexps   javaMillis   regexMillis   quotient
# 0              1          131           282       0.46
# 1            101          122           102       1.19
# 2            201          120           102       1.17
# 3            301          109           107       1.01
# 4            401          113            93       1.21
# 5            501          109            98       1.11
# 6            601          108            97       1.11
# 7            701          134           100       1.34
# 8            801          113            99       1.14
# 9            901          121           116       1.04
# 10          1001          114           103       1.10
# 11          1101          125            99       1.26
# 12          1201          121            98       1.23
# 13          1301          115            96       1.19
# 14          1401          113            96       1.17
# 15          1501          107            97       1.10
# 16          1601          112            97       1.15
# 17          1701          114            91       1.25
# 18          1801          106            91       1.16
# 19          1901          113            97       1.16
# 20          2001          106            98       1.08
# 21          2101          118            95       1.24
# 22          2201          135            92       1.46
# 23          2301          116            91       1.27
# 24          2401          127            93       1.36
# 25          2501          110            93       1.18
# 26          2601          120           102       1.17
# 27          2701          109            94       1.15
# 28          2801          108            90       1.20
# 29          2901          108           100       1.08
# 30          3001          121            96       1.26
# 31          3101          135            91       1.48
# 32          3201          136            98       1.38
# 33          3301          123            92       1.33
# 34          3401          106            95       1.11
# 35          3501          125            98       1.27
# 36          3601          109           103       1.05
# 37          3701          134           107       1.25
# 38          3801          110           100       1.10
# 39          3901          120            97       1.23
# 40          4001          121            96       1.26
# 41          4101          120            97       1.23
# 42          4201          115            95       1.21
# 43          4301          109            97       1.12
# 44          4401          105            96       1.09
# 45          4501          124            91       1.36
# 46          4601          109           100       1.09
# 47          4701          109           100       1.09
# 48          4801          114            95       1.20
# 49          4901          110            98       1.12
# 50          5001          110            94       1.17
# 51          5101          108            95       1.13
# 52          5201          110           102       1.07
# 53          5301          122            92       1.32
# 54          5401          107            98       1.09
# 55          5501          110            94       1.17
# 56          5601          108            94       1.14
# 57          5701          127            95       1.33
# 58          5801          108            90       1.20
# 59          5901          124            97       1.27
# 60          6001          118            93       1.26
# 61          6101          114           103       1.10
# 62          6201          117            97       1.20
# 63          6301          117           101       1.15
# 64          6401          117           103       1.13
# 65          6501          117            96       1.21
# 66          6601          118            98       1.20
# 67          6701          116            98       1.18
# 68          6801          129           102       1.26
# 69          6901          109            94       1.15
# 70          7001          156           158       0.98
# 71          7101          147           122       1.20
# 72          7201          137           117       1.17
# 73          7301          141           121       1.16
# 74          7401          126           107       1.17
# 75          7501          139           109       1.27
# 76          7601          119           105       1.13
# 77          7701          110           101       1.08
# 78          7801          124           102       1.21
# 79          7901          159           105       1.51
# 80          8001          136           113       1.20
# 81          8101          151           100       1.51
# 82          8201          133           108       1.23
# 83          8301          229           166       1.37
# 84          8401          155           122       1.27
# 85          8501          146           127       1.14
# 86          8601          126           108       1.16
# 87          8701          130           112       1.16
# 88          8801          116           108       1.07
# 89          8901          134           103       1.30
# 90          9001          124           114       1.08
# 91          9101          125           106       1.17
# 92          9201          135           127       1.06
# 93          9301          124           108       1.14
# 94          9401          136           102       1.33
# 95          9501          146           119       1.22
# 96          9601          118           102       1.15
# 97          9701          112           107       1.04
# 98          9801          123           108       1.13
# 99          9901          116           107       1.08
# 100        10001          116            95       1.22
# 101        10101          121           106       1.14
# 102        10201          112           100       1.12
# 103        10301          107            96       1.11
# 104        10401          107           103       1.03

# %%
plt.plot(df["NoOfRegexps"], df[" javaMillis"], label="javaMillis")
plt.plot(df["NoOfRegexps"], df[" regexMillis"], label="rmatchMillis")
plt.legend()
plt.show()

# %%
plt.plot(df["NoOfRegexps"], df[" quotient"], label="quotient")
plt.legend()
plt.show()

# %%
df[" quotient"].std()
# Out:
# 0.12511474586834134

# %%
df[" quotient"].mean()
# Out:
# 1.181047619047619

# %%
df[" javaMillis"].std()
# Out:
# 16.22013739593032

# %%
df[" javaMillis"].mean()
# Out:
# 121.65714285714286

# %%
df[" regexMillis"].std()
# Out:
# 21.037869221761536

# %%
df[" regexMillis"].mean()
# Out:
# 103.81904761904762
