# %% [markdown]
# # Benchmarking
# This is a first stab at making benchmarks from Python instead of shell/gnuplot, which is the method that has been used until now.
# It may make sense to add code for generating new benchmark numbers, e.g. using one of the methods
# [listed in this stackoverflow article](https://stackoverflow.com/questions/3652554/calling-java-from-python), or anything else really
#
# The main motivation behind revamping the test setup is not really to use python, but to uncover more information about the
# actual performance.  For instance, it seems like the regex matcher at present has an 18% disadvantage wrs to java matching.
# However, that is based on the "unfair test", which is deliberately unfair, giving java a good chance to outperform rmatch.
#
# Also the the test runs are short, and there may be benefit in running more extensive tests, both with respect to
# length of input and with respect to number of regular expressions.  The complexity of the expressions should also be
# variable.
#
# However, the idea of benchmarking towards the java regex library is still a good one, and one that the revamped test regime should
# build on.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# TODO: Maybe fix the date formatting using [this trick](https://stackoverflow.com/questions/23294197/plotting-chart-with-epoch-time-x-axis-using-matplotlib).

# %%
df0 = pd.read_csv('rmatch-tester/measurements/handle-the-wuthering-heights-corpus.csv')
df1 = df0.tail(5)

# %%
plt.plot(df1["secondsSinceEpoch"], df1["memoryInMb"], label="memoryInMb")
plt.legend()
plt.show()

# %%
plt.plot(df1["secondsSinceEpoch"], df1["millisDuration"], label="millisDuration")
plt.yscale("log")
plt.legend()
plt.show()

# %%
df = pd.read_csv('rmatch-tester/logs/logfile-2023-05-08-20:37:45.csv')

# %%
plt.plot(df["NoOfRegexps"], df[" javaMillis"], label="javaMillis")
plt.plot(df["NoOfRegexps"], df[" regexMillis"], label="rmatchMillis")
plt.legend()
plt.show()

# %%
plt.plot(df["NoOfRegexps"], df[" quotient"], label="quotient")
plt.legend()
plt.show()

# %%
df[" quotient"].std()
# Out:
# 0.12511474586834134

# %%
df[" quotient"].mean()
# Out:
# 1.181047619047619

# %%
df[" javaMillis"].std()
# Out:
# 16.22013739593032

# %%
df[" javaMillis"].mean()
# Out:
# 121.65714285714286

# %%
df[" regexMillis"].std()
# Out:
# 21.037869221761536

# %%
df[" regexMillis"].mean()
# Out:
# 103.81904761904762

# %% [markdown]
# # Study the large corpus test and evolution over time

# %%
largeCorpusDf = pd.read_csv('./rmatch-tester/logs/large-corpus-log.csv')

# %%
largeCorpusDf
# Out:
#          timestamp                          testSeriesId metadata
# 0    1684151426228  99d2b216-dc52-44c0-b379-3a74a11681a7   master  \
# 1    1684151734259  e3b088d2-65a6-4766-994f-a6bcb020ae63   master
# 2    1684152005265  42bb90f0-1649-490b-8826-f918c9092e6a   master
# 3    1684152107237  700981ac-a4cd-49a1-9ee3-f17d288559a9   master
# 4    1684152163314  0f75451c-5881-456c-9eea-d3e5207e35c1   master
# ..             ...                                   ...      ...
# 174  1695592582360  0c2e04cf-451a-41ed-ab2c-0c9e9328663c   master
# 175  1695592836207  ce299a2c-f979-4b64-953a-fc79e563c775   master
# 176  1697657132132  0bd00c3b-8481-4109-b48b-e3be3ad8cb40   master
# 177  1697657267528  c1aec69d-c734-4971-aa36-9f858f36d957   master
# 178  1697658537445  2284cd3e-2178-4221-9e6f-e56be78c8154   master
#
#     matcherTypeName1  usedMemoryInMb1  durationInMillis1 matcherTypeName2
# 0             rmatch              917               4475             java  \
# 1             rmatch              599               6621             java
# 2             rmatch              247               4169             java
# 3             rmatch              769              19949             java
# 4             rmatch              171               9560             java
# ..               ...              ...                ...              ...
# 174           rmatch             2747             253478             java
# 175           rmatch             1991             172404             java
# 176           rmatch             2520             105439             java
# 177           rmatch             2366              76525             java
# 178           rmatch             1676              50118             java
#
#      usedMemoryInMb2  durationInMillis2  noOfMatches  noOfMismatches
# 0                 54                391            0           96068  \
# 1                 55                375            0           96068
# 2                 54                351        96068               0
# 3                148               1709       207832            6111
# 4                100                950       142322             262
# ..               ...                ...          ...             ...
# 174              406               6414       657323              12
# 175              407              10512       657323              12
# 176              406               8089       657323              12
# 177              407               8264       657323              12
# 178              406               4033       657323              12
#
#      noOfRegexps  corpusLength  2to1Ratio
# 0        1154369       1179077   0.000000
# 1        1154369       1179077   0.000000
# 2        1154369       1179077   0.000000
# 3        1154369       1179077   0.000000
# 4        1154369       1179077   0.000000
# ..           ...           ...        ...
# 174        19566        662077  39.519490
# 175        19566        662077  16.400684
# 176        19566        662077  13.034862
# 177        19566        662077   9.260043
# 178        19566        662077  12.426977
#
# [179 rows x 14 columns]

# %%
largeCorpusDf["regexPerMilli1"] = (largeCorpusDf["noOfRegexps"]  *  largeCorpusDf["corpusLength"]) /   largeCorpusDf["durationInMillis1"]
largeCorpusDf["regexPerMilli2"] = (largeCorpusDf["noOfRegexps"]  *  largeCorpusDf["corpusLength"]) /   largeCorpusDf["durationInMillis2"]
largeCorpusDf["regex2to1ratio"] = largeCorpusDf["regexPerMilli2"] /   largeCorpusDf["regexPerMilli1"]

# %%
largeCorpusDf
# Out:
#          timestamp                          testSeriesId metadata
# 0    1684151426228  99d2b216-dc52-44c0-b379-3a74a11681a7   master  \
# 1    1684151734259  e3b088d2-65a6-4766-994f-a6bcb020ae63   master
# 2    1684152005265  42bb90f0-1649-490b-8826-f918c9092e6a   master
# 3    1684152107237  700981ac-a4cd-49a1-9ee3-f17d288559a9   master
# 4    1684152163314  0f75451c-5881-456c-9eea-d3e5207e35c1   master
# ..             ...                                   ...      ...
# 174  1695592582360  0c2e04cf-451a-41ed-ab2c-0c9e9328663c   master
# 175  1695592836207  ce299a2c-f979-4b64-953a-fc79e563c775   master
# 176  1697657132132  0bd00c3b-8481-4109-b48b-e3be3ad8cb40   master
# 177  1697657267528  c1aec69d-c734-4971-aa36-9f858f36d957   master
# 178  1697658537445  2284cd3e-2178-4221-9e6f-e56be78c8154   master
#
#     matcherTypeName1  usedMemoryInMb1  durationInMillis1 matcherTypeName2
# 0             rmatch              917               4475             java  \
# 1             rmatch              599               6621             java
# 2             rmatch              247               4169             java
# 3             rmatch              769              19949             java
# 4             rmatch              171               9560             java
# ..               ...              ...                ...              ...
# 174           rmatch             2747             253478             java
# 175           rmatch             1991             172404             java
# 176           rmatch             2520             105439             java
# 177           rmatch             2366              76525             java
# 178           rmatch             1676              50118             java
#
#      usedMemoryInMb2  durationInMillis2  noOfMatches  noOfMismatches
# 0                 54                391            0           96068  \
# 1                 55                375            0           96068
# 2                 54                351        96068               0
# 3                148               1709       207832            6111
# 4                100                950       142322             262
# ..               ...                ...          ...             ...
# 174              406               6414       657323              12
# 175              407              10512       657323              12
# 176              406               8089       657323              12
# 177              407               8264       657323              12
# 178              406               4033       657323              12
#
#      noOfRegexps  corpusLength  2to1Ratio  regexPerMilli1  regexPerMilli2
# 0        1154369       1179077   0.000000    3.041542e+08    3.481048e+09  \
# 1        1154369       1179077   0.000000    2.055717e+08    3.629573e+09
# 2        1154369       1179077   0.000000    3.264788e+08    3.877749e+09
# 3        1154369       1179077   0.000000    6.822848e+07    7.964248e+08
# 4        1154369       1179077   0.000000    1.423734e+08    1.432726e+09
# ..           ...           ...        ...             ...             ...
# 174        19566        662077  39.519490    5.110581e+04    2.019675e+06
# 175        19566        662077  16.400684    7.513862e+04    1.232325e+06
# 176        19566        662077  13.034862    1.228596e+05    1.601459e+06
# 177        19566        662077   9.260043    1.692806e+05    1.567546e+06
# 178        19566        662077  12.426977    2.584740e+05    3.212050e+06
#
#      regex2to1ratio
# 0         11.445013
# 1         17.656000
# 2         11.877493
# 3         11.672908
# 4         10.063158
# ..              ...
# 174       39.519489
# 175       16.400685
# 176       13.034862
# 177        9.260044
# 178       12.426977
#
# [179 rows x 17 columns]

# %%
plt.plot(largeCorpusDf["timestamp"], largeCorpusDf["regex2to1ratio"], label="quotient")
plt.legend()
plt.show()

# %%
lastTen = largeCorpusDf.iloc[-10:]
plt.plot(lastTen["timestamp"], lastTen["regex2to1ratio"], label="quotient")
plt.legend()
plt.show()

# %%
lastTen
# Out:
#          timestamp                          testSeriesId metadata
# 169  1695500237614  93b4c6c8-d003-4220-a0da-f28cee4f47ce   master  \
# 170  1695575363673  b198d2e2-4802-4acd-af92-bc38218d1e95   master
# 171  1695575996695  7bb391a5-2f39-4e45-bbb3-c812e251f1c2   master
# 172  1695578259490  bed0c449-1742-48f5-b5e4-3fe421ba43f3   master
# 173  1695591108293  79cae25a-affe-41af-8d98-654cb5149ee3   master
# 174  1695592582360  0c2e04cf-451a-41ed-ab2c-0c9e9328663c   master
# 175  1695592836207  ce299a2c-f979-4b64-953a-fc79e563c775   master
# 176  1697657132132  0bd00c3b-8481-4109-b48b-e3be3ad8cb40   master
# 177  1697657267528  c1aec69d-c734-4971-aa36-9f858f36d957   master
# 178  1697658537445  2284cd3e-2178-4221-9e6f-e56be78c8154   master
#
#     matcherTypeName1  usedMemoryInMb1  durationInMillis1 matcherTypeName2
# 169           rmatch             1652             162909             java  \
# 170           rmatch             2771             206664             java
# 171           rmatch             3244             222493             java
# 172           rmatch             1222             161874             java
# 173           rmatch             2115             238636             java
# 174           rmatch             2747             253478             java
# 175           rmatch             1991             172404             java
# 176           rmatch             2520             105439             java
# 177           rmatch             2366              76525             java
# 178           rmatch             1676              50118             java
#
#      usedMemoryInMb2  durationInMillis2  noOfMatches  noOfMismatches
# 169              406               8117       657323              12  \
# 170              408              32328       657323              12
# 171              409              20023       657323              12
# 172              245              11678       318135          339188
# 173              413              47162       657323              12
# 174              406               6414       657323              12
# 175              407              10512       657323              12
# 176              406               8089       657323              12
# 177              407               8264       657323              12
# 178              406               4033       657323              12
#
#      noOfRegexps  corpusLength  2to1Ratio  regexPerMilli1  regexPerMilli2
# 169        19566        662077  20.070099    79518.004420    1.595934e+06  \
# 170        19566        662077   6.392724    62682.414847    4.007114e+05
# 171        19566        662077  11.111872    58222.948956    6.469659e+05
# 172        19566        662077  13.861449    80026.431558    1.109282e+06
# 173        19566        662077   5.059921    54284.343444    2.746745e+05
# 174        19566        662077  39.519490    51105.810295    2.019675e+06
# 175        19566        662077  16.400684    75138.619649    1.232325e+06
# 176        19566        662077  13.034862   122859.649485    1.601459e+06
# 177        19566        662077   9.260043   169280.608716    1.567546e+06
# 178        19566        662077  12.426977   258473.973064    3.212050e+06
#
#      regex2to1ratio
# 169       20.070100
# 170        6.392725
# 171       11.111871
# 172       13.861449
# 173        5.059921
# 174       39.519489
# 175       16.400685
# 176       13.034862
# 177        9.260044
# 178       12.426977

# %%
import sqlite3

# %%
df = pd.read_csv('./rmatch-tester/logs/large-corpus-log.csv')
print(df)
# Out:
#          timestamp                          testSeriesId metadata
# 0    1684151426228  99d2b216-dc52-44c0-b379-3a74a11681a7   master  \
# 1    1684151734259  e3b088d2-65a6-4766-994f-a6bcb020ae63   master
# 2    1684152005265  42bb90f0-1649-490b-8826-f918c9092e6a   master
# 3    1684152107237  700981ac-a4cd-49a1-9ee3-f17d288559a9   master
# 4    1684152163314  0f75451c-5881-456c-9eea-d3e5207e35c1   master
# ..             ...                                   ...      ...
# 174  1695592582360  0c2e04cf-451a-41ed-ab2c-0c9e9328663c   master
# 175  1695592836207  ce299a2c-f979-4b64-953a-fc79e563c775   master
# 176  1697657132132  0bd00c3b-8481-4109-b48b-e3be3ad8cb40   master
# 177  1697657267528  c1aec69d-c734-4971-aa36-9f858f36d957   master
# 178  1697658537445  2284cd3e-2178-4221-9e6f-e56be78c8154   master
#
#     matcherTypeName1  usedMemoryInMb1  durationInMillis1 matcherTypeName2
# 0             rmatch              917               4475             java  \
# 1             rmatch              599               6621             java
# 2             rmatch              247               4169             java
# 3             rmatch              769              19949             java
# 4             rmatch              171               9560             java
# ..               ...              ...                ...              ...
# 174           rmatch             2747             253478             java
# 175           rmatch             1991             172404             java
# 176           rmatch             2520             105439             java
# 177           rmatch             2366              76525             java
# 178           rmatch             1676              50118             java
#
#      usedMemoryInMb2  durationInMillis2  noOfMatches  noOfMismatches
# 0                 54                391            0           96068  \
# 1                 55                375            0           96068
# 2                 54                351        96068               0
# 3                148               1709       207832            6111
# 4                100                950       142322             262
# ..               ...                ...          ...             ...
# 174              406               6414       657323              12
# 175              407              10512       657323              12
# 176              406               8089       657323              12
# 177              407               8264       657323              12
# 178              406               4033       657323              12
#
#      noOfRegexps  corpusLength  2to1Ratio
# 0        1154369       1179077   0.000000
# 1        1154369       1179077   0.000000
# 2        1154369       1179077   0.000000
# 3        1154369       1179077   0.000000
# 4        1154369       1179077   0.000000
# ..           ...           ...        ...
# 174        19566        662077  39.519490
# 175        19566        662077  16.400684
# 176        19566        662077  13.034862
# 177        19566        662077   9.260043
# 178        19566        662077  12.426977
#
# [179 rows x 14 columns]

# %%
import os
dbfile = 'measurements.sqlite'
if os.path.exists(dbfile):
    os.remove(dbfile)

# %%
table_name = 'Measurements'

query = f'Create table if not Exists {table_name} (timestamp,testSeriesId,metadata,matcherTypeName1,usedMemoryInMb1,durationInMillis1,matcherTypeName2,usedMemoryInMb2,durationInMillis2,noOfMatches,noOfMismatches,noOfRegexps,corpusLength,"2to1Ratio")'

# %%
conn = sqlite3.connect(dbfile)
conn.execute(query)
df.to_sql(table_name,conn,if_exists='replace',index=False)
conn.commit()
conn.close()

# %%
conn = sqlite3.connect(dbfile)
r_df = pd.read_sql("select * from Measurements",conn)
print(r_df)
# Out:
#          timestamp                          testSeriesId metadata
# 0    1684151426228  99d2b216-dc52-44c0-b379-3a74a11681a7   master  \
# 1    1684151734259  e3b088d2-65a6-4766-994f-a6bcb020ae63   master
# 2    1684152005265  42bb90f0-1649-490b-8826-f918c9092e6a   master
# 3    1684152107237  700981ac-a4cd-49a1-9ee3-f17d288559a9   master
# 4    1684152163314  0f75451c-5881-456c-9eea-d3e5207e35c1   master
# ..             ...                                   ...      ...
# 174  1695592582360  0c2e04cf-451a-41ed-ab2c-0c9e9328663c   master
# 175  1695592836207  ce299a2c-f979-4b64-953a-fc79e563c775   master
# 176  1697657132132  0bd00c3b-8481-4109-b48b-e3be3ad8cb40   master
# 177  1697657267528  c1aec69d-c734-4971-aa36-9f858f36d957   master
# 178  1697658537445  2284cd3e-2178-4221-9e6f-e56be78c8154   master
#
#     matcherTypeName1  usedMemoryInMb1  durationInMillis1 matcherTypeName2
# 0             rmatch              917               4475             java  \
# 1             rmatch              599               6621             java
# 2             rmatch              247               4169             java
# 3             rmatch              769              19949             java
# 4             rmatch              171               9560             java
# ..               ...              ...                ...              ...
# 174           rmatch             2747             253478             java
# 175           rmatch             1991             172404             java
# 176           rmatch             2520             105439             java
# 177           rmatch             2366              76525             java
# 178           rmatch             1676              50118             java
#
#      usedMemoryInMb2  durationInMillis2  noOfMatches  noOfMismatches
# 0                 54                391            0           96068  \
# 1                 55                375            0           96068
# 2                 54                351        96068               0
# 3                148               1709       207832            6111
# 4                100                950       142322             262
# ..               ...                ...          ...             ...
# 174              406               6414       657323              12
# 175              407              10512       657323              12
# 176              406               8089       657323              12
# 177              407               8264       657323              12
# 178              406               4033       657323              12
#
#      noOfRegexps  corpusLength  2to1Ratio
# 0        1154369       1179077   0.000000
# 1        1154369       1179077   0.000000
# 2        1154369       1179077   0.000000
# 3        1154369       1179077   0.000000
# 4        1154369       1179077   0.000000
# ..           ...           ...        ...
# 174        19566        662077  39.519490
# 175        19566        662077  16.400684
# 176        19566        662077  13.034862
# 177        19566        662077   9.260043
# 178        19566        662077  12.426977
#
# [179 rows x 14 columns]

# %%
with open('summarize-large-corpus-trials.sql', 'r') as file:
    summarizerSql = file.read().rstrip()

# %%
summarizerSql
# Out:
# "select min(timestamp) as timestamp,\n       testSeriesId,\n       metadata,\n       noOfMatches,\n       noOfMismatches,\n       corpusLength,\n       noOfRegexps,\n       min(durationInMillis2) as 'minJavaDuration',\n       max(durationInMillis2) as 'maxJavaDuration',\n       avg(durationInMillis2) as 'avgJavaDuration',\n       min(durationInMillis1) as 'minRegexDuration',\n       max(durationInMillis1) as 'maxRegexDuration',\n       avg(durationInMillis1) as 'avgRegexDuration',\n--       stdev(durationInMillis2) as 'stdevJavaDuration',\n--       stdev(durationInMillis1) as 'stdevRegexDuration',\n       ((1.0*min(durationInMillis1))/6154) as 'againstBestJavaRatio',\n       ((1.0*min(durationInMillis1))/(1.0*min(durationInMillis2))) as 'minMinRatio',\n       ((1.0*max(durationInMillis1))/(1.0*max(durationInMillis2))) as 'maxMaxRatio',\n       ((1.0*avg(durationInMillis1))/(1.0*avg(durationInMillis2))) as 'avgAvgRatio'\n--       ((1.0*stdev(durationInMillis1))/(1.0*stdev(durationInMillis2))) as 'stdevStdevRatio'\nfrom Measurements  where timestamp >= 1685300128023 group by testSeriesId  order by timestamp asc;"

# %%
conn = sqlite3.connect(dbfile)
r_df = pd.read_sql(summarizerSql, conn)

print(r_df)
conn.close()
# Out:
#         timestamp                          testSeriesId
# 0   1685300128023  A9B69B90-AAB2-4AD3-A421-5E232DF8C8BD  \
# 1   1685374976474  8383FDD9-A509-4046-8F04-FD430BB07BA8
# 2   1685380210149  28CC3751-BA44-4B0D-BA81-27F159A3079C
# 3   1685390284561  58C63D2D-F066-415C-AE24-E045B873D387
# 4   1685395218314  73EE6D74-51C3-46AD-9650-47FAD020E03E
# ..            ...                                   ...
# 78  1695592582360  0c2e04cf-451a-41ed-ab2c-0c9e9328663c
# 79  1695592836207  ce299a2c-f979-4b64-953a-fc79e563c775
# 80  1697657132132  0bd00c3b-8481-4109-b48b-e3be3ad8cb40
# 81  1697657267528  c1aec69d-c734-4971-aa36-9f858f36d957
# 82  1697658537445  2284cd3e-2178-4221-9e6f-e56be78c8154
#
#                               metadata  noOfMatches  noOfMismatches
# 0   u/la3lma/refactoring-a-la-chatgpt2      1144409               8  \
# 1                               master      1144409               8
# 2      u/la3lma/optimize-using-chatgtp      1144409               8
# 3   u/la3lma/refactoring-a-la-chatgpt2      1144409               8
# 4                               master      1144409               8
# ..                                 ...          ...             ...
# 78                              master       657323              12
# 79                              master       657323              12
# 80                              master       657323              12
# 81                              master       657323              12
# 82                              master       657323              12
#
#     corpusLength  noOfRegexps  minJavaDuration  maxJavaDuration
# 0        1154369        19566            10009            21266  \
# 1        1154369        19566             6147            17757
# 2        1154369        19566             9492            63137
# 3        1154369        19566             6154            20161
# 4        1154369        19566             8824            14363
# ..           ...          ...              ...              ...
# 78        662077        19566             6414             6414
# 79        662077        19566            10512            10512
# 80        662077        19566             8089             8089
# 81        662077        19566             8264             8264
# 82        662077        19566             4033             4033
#
#     avgJavaDuration  minRegexDuration  maxRegexDuration  avgRegexDuration
# 0           14724.6            134888            265588          192971.0  \
# 1           11564.7             69792            164391          141148.1
# 2           16955.2            102796            209465          147334.0
# 3           11824.1             72052            202999          142595.8
# 4           10677.6            151514            343727          204564.9
# ..              ...               ...               ...               ...
# 78           6414.0            253478            253478          253478.0
# 79          10512.0            172404            172404          172404.0
# 80           8089.0            105439            105439          105439.0
# 81           8264.0             76525             76525           76525.0
# 82           4033.0             50118             50118           50118.0
#
#     againstBestJavaRatio  minMinRatio  maxMaxRatio  avgAvgRatio
# 0              21.918752    13.476671    12.488855    13.105348
# 1              11.340916    11.353831     9.257814    12.205081
# 2              16.703932    10.829751     3.317627     8.689606
# 3              11.708157    11.708157    10.068895    12.059759
# 4              24.620409    17.170671    23.931421    19.158322
# ..                   ...          ...          ...          ...
# 78             41.189145    39.519489    39.519489    39.519489
# 79             28.014950    16.400685    16.400685    16.400685
# 80             17.133409    13.034862    13.034862    13.034862
# 81             12.435002     9.260044     9.260044     9.260044
# 82              8.143971    12.426977    12.426977    12.426977
#
# [83 rows x 17 columns]

# %%
lastTen = r_df.iloc[-100:]
plt.plot(r_df["timestamp"], lastTen["minMinRatio"], label="quotient")
plt.legend()
plt.show()

# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
q = "select  timestamp as t,  (1.0*durationInMillis1)/(1.0*noOfMatches) as d1,    (1.0*durationInMillis2)/(1.0*noOfMatches) as d2  from Measurements where noofMatches > 10000 AND d2 < 12*d1 order by t;"

conn = sqlite3.connect(dbfile)
r_df = pd.read_sql(q, conn)

print(r_df)
conn.close()

# Create a new figure
fig = plt.figure()

# Create 3D subplot
# The '111' means 1x1 grid, first subplot, similar to MATLAB-style
ax = fig.add_subplot(111, projection='3d')

# Extract data from DataFrame
t = r_df['t']
d1 = r_df['d1']
d2 = r_df['d2']

# Scatter plot
ax.scatter(d1, d2, t)

#Adding lines
ax.plot(d1, d2, t, color='grey', linewidth=0.5)

# Adding labels
ax.set_xlabel('d1')
ax.set_ylabel('d2')
ax.set_zlabel('t')

# Show plot
plt.show()
# Out:
#                  t        d1        d2
# 0    1684152005265  0.043396  0.003654
# 1    1684152107237  0.095986  0.008223
# 2    1684152163314  0.067172  0.006675
# 3    1684152191817  0.058054  0.005566
# 4    1684152222095  0.055206  0.004797
# ..             ...       ...       ...
# 166  1695592582360  0.385622  0.009758
# 167  1695592836207  0.262282  0.015992
# 168  1697657132132  0.160407  0.012306
# 169  1697657267528  0.116419  0.012572
# 170  1697658537445  0.076246  0.006135
#
# [171 rows x 3 columns]
# <img src="data:image/png;base64,..." width="640">
